# %%
import models
import os
import torch
from torch import optim, nn
from torchvision import transforms, datasets
import torchvision
import common

# %%
#DIRECTORY SETTINGS
os.chdir("..")#Go up two directories
SAVE_DIR = 'models'
MODEL_SAVE_PATH = os.path.join(SAVE_DIR, 'base.pt')


#HYPERPARAMETERS
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

EPOCHS=100
BATCH_SIZE = 32
criterion = nn.CrossEntropyLoss()
ADAM_OPTIMISER=True
LEARNING_RATE=0.001

# %%
train_transforms = transforms.Compose([# Data Transforms
                           transforms.Resize(256),#Resize
                           transforms.RandomHorizontalFlip(30),#Flip
                           transforms.RandomRotation(10),#Roatate
                           transforms.RandomCrop(256),#Crop
                           transforms.ToTensor(),#Convert to Tensor
                           transforms.Normalize((0.49139968, 0.48215827, 0.44653124), (0.24703233, 0.24348505, 0.26158768))#Normalize
                       ])

test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.49139968, 0.48215827, 0.44653124), (0.24703233, 0.24348505, 0.26158768))
                       ])

# %%
train_data = torchvision.datasets.CIFAR10(root='data', train=True, download=True, transform=train_transforms)#Use CIFAR10 to train
train_data, valid_data = torch.utils.data.random_split(train_data, [int(len(train_data)*0.9), len(train_data) - int(len(train_data)*0.9)])
test_data = torchvision.datasets.CIFAR10(root='data', train=False, download=True, transform=test_transforms)


print(f'Number of training examples: {len(train_data)}')
print(f'Number of validation examples: {len(valid_data)}')
print(f'Number of testing examples: {len(test_data)}')


train_iterator = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=BATCH_SIZE)
valid_iterator = torch.utils.data.DataLoader(valid_data, batch_size=BATCH_SIZE)
test_iterator = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE)
# Out:
# 0.0%
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 1.8%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 4.8%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 7.8%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 10.9%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 13.9%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 17.0%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 20.0%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 23.1%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 26.1%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 29.2%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 32.2%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 35.2%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 38.3%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 41.2%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 44.2%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 47.1%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 50.0%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 53.0%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 56.0%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 59.0%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 61.9%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 64.8%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 78.8%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 81.7%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 84.5%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 87.5%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 100.0%
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Number of training examples: 45000
# Number of validation examples: 5000
# Number of testing examples: 10000

# %%
model = torchvision.models.resnet18(pretrained=True)#TorchVision

for param in model.parameters():
    param.requires_grad = False
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 10)
model = model.to(device)

#Hyperparameters
if(ADAM_OPTIMISER):
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
else:
    optimizer = optim.SGD(model.classifier.parameters(), lr=0.001, momentum=0.5)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/tsamak/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 52.5%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 100.0%

# %%
#Train
best_valid_loss = float('inf')
for epoch in range(EPOCHS):#Range of Epochs
    print(epoch)
    train_loss, train_acc = common.train(model, device, train_iterator, optimizer, criterion)#Train Loss Calculation
    valid_loss, valid_acc = common.evaluate(model, device, valid_iterator, criterion)#Validation Loss Calculation

    if valid_loss < best_valid_loss:#Validation Loss - Is current lower than the saved validation loss.
        best_valid_loss = valid_loss#Save the best loss (lowest)
        torch.save(model.state_dict(), MODEL_SAVE_PATH)#Save the model

    print(f'| Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:05.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:05.2f}% |')
# Out:
# 0
# | Epoch: 01 | Train Loss: 0.996 | Train Acc: 66.91% | Val. Loss: 0.783 | Val. Acc: 73.09% |
# 1
# | Epoch: 02 | Train Loss: 0.779 | Train Acc: 72.98% | Val. Loss: 0.741 | Val. Acc: 74.32% |
# 2
# | Epoch: 03 | Train Loss: 0.757 | Train Acc: 73.75% | Val. Loss: 0.674 | Val. Acc: 76.19% |
# 3
# | Epoch: 04 | Train Loss: 0.735 | Train Acc: 74.63% | Val. Loss: 0.682 | Val. Acc: 76.37% |
# 4
# | Epoch: 05 | Train Loss: 0.721 | Train Acc: 75.06% | Val. Loss: 0.672 | Val. Acc: 76.63% |
# 5
# | Epoch: 06 | Train Loss: 0.724 | Train Acc: 74.92% | Val. Loss: 0.674 | Val. Acc: 77.09% |
# 6
# | Epoch: 07 | Train Loss: 0.717 | Train Acc: 75.18% | Val. Loss: 0.760 | Val. Acc: 74.18% |
# 7
# | Epoch: 08 | Train Loss: 0.712 | Train Acc: 75.38% | Val. Loss: 0.678 | Val. Acc: 76.53% |
# 8
# | Epoch: 09 | Train Loss: 0.710 | Train Acc: 75.25% | Val. Loss: 0.691 | Val. Acc: 75.50% |
# 9
# | Epoch: 10 | Train Loss: 0.708 | Train Acc: 75.53% | Val. Loss: 0.659 | Val. Acc: 77.55% |
# 10
# | Epoch: 11 | Train Loss: 0.707 | Train Acc: 75.70% | Val. Loss: 0.688 | Val. Acc: 76.29% |
# 11
# | Epoch: 12 | Train Loss: 0.707 | Train Acc: 75.55% | Val. Loss: 0.642 | Val. Acc: 77.97% |
# 12
# | Epoch: 13 | Train Loss: 0.705 | Train Acc: 75.60% | Val. Loss: 0.656 | Val. Acc: 76.89% |
# 13
# | Epoch: 14 | Train Loss: 0.701 | Train Acc: 75.91% | Val. Loss: 0.667 | Val. Acc: 76.89% |
# 14
# | Epoch: 15 | Train Loss: 0.703 | Train Acc: 75.80% | Val. Loss: 0.651 | Val. Acc: 77.35% |
# 15
# | Epoch: 16 | Train Loss: 0.702 | Train Acc: 75.49% | Val. Loss: 0.687 | Val. Acc: 76.39% |
# 16
# | Epoch: 17 | Train Loss: 0.694 | Train Acc: 75.82% | Val. Loss: 0.666 | Val. Acc: 76.31% |
# 17
# | Epoch: 18 | Train Loss: 0.700 | Train Acc: 75.81% | Val. Loss: 0.665 | Val. Acc: 77.23% |
# 18
# | Epoch: 19 | Train Loss: 0.693 | Train Acc: 76.02% | Val. Loss: 0.703 | Val. Acc: 76.04% |
# 19
# | Epoch: 20 | Train Loss: 0.692 | Train Acc: 76.25% | Val. Loss: 0.635 | Val. Acc: 78.28% |
# 20
# | Epoch: 21 | Train Loss: 0.702 | Train Acc: 75.72% | Val. Loss: 0.686 | Val. Acc: 76.85% |
# 21
# | Epoch: 22 | Train Loss: 0.695 | Train Acc: 76.05% | Val. Loss: 0.665 | Val. Acc: 76.61% |
# 22
# | Epoch: 23 | Train Loss: 0.699 | Train Acc: 75.84% | Val. Loss: 0.657 | Val. Acc: 77.25% |
# 23
# | Epoch: 24 | Train Loss: 0.689 | Train Acc: 76.20% | Val. Loss: 0.650 | Val. Acc: 77.47% |
# 24
# | Epoch: 25 | Train Loss: 0.684 | Train Acc: 76.43% | Val. Loss: 0.637 | Val. Acc: 77.73% |
# 25
# | Epoch: 26 | Train Loss: 0.690 | Train Acc: 76.26% | Val. Loss: 0.644 | Val. Acc: 77.77% |
# 26
# | Epoch: 27 | Train Loss: 0.691 | Train Acc: 76.08% | Val. Loss: 0.616 | Val. Acc: 78.56% |
# 27
# | Epoch: 28 | Train Loss: 0.687 | Train Acc: 76.23% | Val. Loss: 0.665 | Val. Acc: 77.11% |
# 28
# | Epoch: 29 | Train Loss: 0.695 | Train Acc: 75.98% | Val. Loss: 0.657 | Val. Acc: 77.53% |
# 29
# | Epoch: 30 | Train Loss: 0.690 | Train Acc: 76.10% | Val. Loss: 0.656 | Val. Acc: 77.23% |
# 30
# | Epoch: 31 | Train Loss: 0.690 | Train Acc: 76.43% | Val. Loss: 0.679 | Val. Acc: 76.93% |
# 31
# | Epoch: 32 | Train Loss: 0.686 | Train Acc: 76.22% | Val. Loss: 0.678 | Val. Acc: 77.27% |
# 32
# | Epoch: 33 | Train Loss: 0.687 | Train Acc: 76.24% | Val. Loss: 0.650 | Val. Acc: 77.47% |
# 33
# | Epoch: 34 | Train Loss: 0.693 | Train Acc: 75.87% | Val. Loss: 0.645 | Val. Acc: 77.61% |
# 34
# | Epoch: 35 | Train Loss: 0.689 | Train Acc: 76.26% | Val. Loss: 0.651 | Val. Acc: 77.15% |
# 35
# | Epoch: 36 | Train Loss: 0.689 | Train Acc: 76.09% | Val. Loss: 0.677 | Val. Acc: 76.37% |
# 36
# | Epoch: 37 | Train Loss: 0.693 | Train Acc: 76.12% | Val. Loss: 0.663 | Val. Acc: 77.09% |
# 37
# | Epoch: 38 | Train Loss: 0.690 | Train Acc: 76.09% | Val. Loss: 0.708 | Val. Acc: 75.86% |
# 38
# | Epoch: 39 | Train Loss: 0.688 | Train Acc: 76.34% | Val. Loss: 0.648 | Val. Acc: 77.95% |
# 39
# | Epoch: 40 | Train Loss: 0.693 | Train Acc: 76.24% | Val. Loss: 0.654 | Val. Acc: 77.65% |
# 40
# | Epoch: 41 | Train Loss: 0.688 | Train Acc: 76.42% | Val. Loss: 0.650 | Val. Acc: 77.73% |
# 41
# | Epoch: 42 | Train Loss: 0.689 | Train Acc: 76.17% | Val. Loss: 0.638 | Val. Acc: 78.22% |
# 42
# | Epoch: 43 | Train Loss: 0.691 | Train Acc: 76.26% | Val. Loss: 0.655 | Val. Acc: 77.97% |
# 43
# | Epoch: 44 | Train Loss: 0.691 | Train Acc: 76.15% | Val. Loss: 0.687 | Val. Acc: 76.75% |
# 44
# | Epoch: 45 | Train Loss: 0.683 | Train Acc: 76.35% | Val. Loss: 0.661 | Val. Acc: 76.67% |
# 45
# | Epoch: 46 | Train Loss: 0.685 | Train Acc: 76.49% | Val. Loss: 0.666 | Val. Acc: 76.75% |
# 46
# | Epoch: 47 | Train Loss: 0.690 | Train Acc: 76.11% | Val. Loss: 0.646 | Val. Acc: 77.95% |
# 47
# | Epoch: 48 | Train Loss: 0.690 | Train Acc: 76.36% | Val. Loss: 0.668 | Val. Acc: 77.05% |
# 48
# | Epoch: 49 | Train Loss: 0.688 | Train Acc: 76.11% | Val. Loss: 0.665 | Val. Acc: 77.11% |
# 49
# | Epoch: 50 | Train Loss: 0.685 | Train Acc: 76.31% | Val. Loss: 0.642 | Val. Acc: 78.22% |
# 50
# | Epoch: 51 | Train Loss: 0.687 | Train Acc: 76.14% | Val. Loss: 0.670 | Val. Acc: 77.39% |
# 51
# | Epoch: 52 | Train Loss: 0.686 | Train Acc: 76.39% | Val. Loss: 0.641 | Val. Acc: 77.47% |
# 52
# | Epoch: 53 | Train Loss: 0.690 | Train Acc: 76.13% | Val. Loss: 0.655 | Val. Acc: 77.71% |
# 53
# | Epoch: 54 | Train Loss: 0.688 | Train Acc: 76.28% | Val. Loss: 0.675 | Val. Acc: 76.89% |
# 54
# | Epoch: 55 | Train Loss: 0.685 | Train Acc: 76.37% | Val. Loss: 0.625 | Val. Acc: 78.22% |
# 55
# | Epoch: 56 | Train Loss: 0.688 | Train Acc: 76.12% | Val. Loss: 0.668 | Val. Acc: 77.55% |
# 56
# | Epoch: 57 | Train Loss: 0.686 | Train Acc: 76.35% | Val. Loss: 0.625 | Val. Acc: 78.30% |
# 57
# | Epoch: 58 | Train Loss: 0.692 | Train Acc: 76.18% | Val. Loss: 0.693 | Val. Acc: 75.92% |
# 58
# | Epoch: 59 | Train Loss: 0.687 | Train Acc: 76.17% | Val. Loss: 0.655 | Val. Acc: 77.43% |
# 59
# | Epoch: 60 | Train Loss: 0.686 | Train Acc: 76.23% | Val. Loss: 0.652 | Val. Acc: 77.67% |
# 60
# | Epoch: 61 | Train Loss: 0.685 | Train Acc: 76.37% | Val. Loss: 0.658 | Val. Acc: 77.43% |
# 61
# | Epoch: 62 | Train Loss: 0.685 | Train Acc: 76.35% | Val. Loss: 0.655 | Val. Acc: 77.21% |
# 62
# | Epoch: 63 | Train Loss: 0.690 | Train Acc: 76.41% | Val. Loss: 0.680 | Val. Acc: 76.95% |
# 63
# | Epoch: 64 | Train Loss: 0.690 | Train Acc: 76.14% | Val. Loss: 0.672 | Val. Acc: 77.01% |
# 64
# | Epoch: 65 | Train Loss: 0.689 | Train Acc: 76.11% | Val. Loss: 0.654 | Val. Acc: 77.75% |
# 65
# | Epoch: 66 | Train Loss: 0.690 | Train Acc: 76.18% | Val. Loss: 0.646 | Val. Acc: 77.65% |
# 66
# | Epoch: 67 | Train Loss: 0.685 | Train Acc: 76.35% | Val. Loss: 0.650 | Val. Acc: 77.99% |
# 67
# | Epoch: 68 | Train Loss: 0.687 | Train Acc: 76.30% | Val. Loss: 0.670 | Val. Acc: 77.01% |
# 68
# | Epoch: 69 | Train Loss: 0.686 | Train Acc: 76.28% | Val. Loss: 0.650 | Val. Acc: 77.55% |
# 69
# | Epoch: 70 | Train Loss: 0.692 | Train Acc: 76.24% | Val. Loss: 0.662 | Val. Acc: 76.89% |
# 70
# | Epoch: 71 | Train Loss: 0.690 | Train Acc: 76.35% | Val. Loss: 0.664 | Val. Acc: 76.95% |
# 71
# | Epoch: 72 | Train Loss: 0.682 | Train Acc: 76.59% | Val. Loss: 0.658 | Val. Acc: 77.27% |
# 72
# | Epoch: 73 | Train Loss: 0.686 | Train Acc: 76.22% | Val. Loss: 0.641 | Val. Acc: 78.20% |
# 73
# | Epoch: 74 | Train Loss: 0.685 | Train Acc: 76.30% | Val. Loss: 0.638 | Val. Acc: 77.75% |
# 74
# | Epoch: 75 | Train Loss: 0.687 | Train Acc: 76.35% | Val. Loss: 0.647 | Val. Acc: 78.32% |
# 75
# | Epoch: 76 | Train Loss: 0.687 | Train Acc: 76.06% | Val. Loss: 0.650 | Val. Acc: 77.63% |
# 76
# | Epoch: 77 | Train Loss: 0.695 | Train Acc: 76.04% | Val. Loss: 0.739 | Val. Acc: 75.10% |
# 77
# | Epoch: 78 | Train Loss: 0.688 | Train Acc: 76.31% | Val. Loss: 0.667 | Val. Acc: 77.43% |
# 78
# | Epoch: 79 | Train Loss: 0.689 | Train Acc: 76.17% | Val. Loss: 0.647 | Val. Acc: 77.51% |
# 79
# | Epoch: 80 | Train Loss: 0.685 | Train Acc: 76.36% | Val. Loss: 0.665 | Val. Acc: 76.97% |
# 80
# | Epoch: 81 | Train Loss: 0.684 | Train Acc: 76.49% | Val. Loss: 0.647 | Val. Acc: 77.91% |
# 81
# | Epoch: 82 | Train Loss: 0.693 | Train Acc: 76.06% | Val. Loss: 0.662 | Val. Acc: 77.59% |
# 82
# | Epoch: 83 | Train Loss: 0.692 | Train Acc: 76.12% | Val. Loss: 0.655 | Val. Acc: 77.65% |
# 83
# | Epoch: 84 | Train Loss: 0.681 | Train Acc: 76.63% | Val. Loss: 0.647 | Val. Acc: 78.28% |
# 84
# | Epoch: 85 | Train Loss: 0.691 | Train Acc: 76.05% | Val. Loss: 0.661 | Val. Acc: 77.03% |
# 85
# | Epoch: 86 | Train Loss: 0.685 | Train Acc: 76.40% | Val. Loss: 0.645 | Val. Acc: 78.03% |
# 86
# | Epoch: 87 | Train Loss: 0.697 | Train Acc: 76.10% | Val. Loss: 0.656 | Val. Acc: 77.53% |
# 87
# | Epoch: 88 | Train Loss: 0.689 | Train Acc: 76.19% | Val. Loss: 0.642 | Val. Acc: 78.09% |
# 88
# | Epoch: 89 | Train Loss: 0.683 | Train Acc: 76.43% | Val. Loss: 0.654 | Val. Acc: 77.75% |
# 89
# | Epoch: 90 | Train Loss: 0.691 | Train Acc: 76.16% | Val. Loss: 0.652 | Val. Acc: 77.59% |
# 90
# | Epoch: 91 | Train Loss: 0.686 | Train Acc: 76.30% | Val. Loss: 0.658 | Val. Acc: 77.01% |
# 91
# | Epoch: 92 | Train Loss: 0.687 | Train Acc: 76.50% | Val. Loss: 0.733 | Val. Acc: 74.80% |
# 92
# | Epoch: 93 | Train Loss: 0.688 | Train Acc: 76.33% | Val. Loss: 0.653 | Val. Acc: 77.51% |
# 93
# | Epoch: 94 | Train Loss: 0.688 | Train Acc: 76.12% | Val. Loss: 0.636 | Val. Acc: 77.85% |
# 94
# | Epoch: 95 | Train Loss: 0.681 | Train Acc: 76.43% | Val. Loss: 0.643 | Val. Acc: 77.89% |
# 95
# | Epoch: 96 | Train Loss: 0.684 | Train Acc: 76.42% | Val. Loss: 0.653 | Val. Acc: 77.15% |
# 96
# | Epoch: 97 | Train Loss: 0.680 | Train Acc: 76.51% | Val. Loss: 0.655 | Val. Acc: 78.09% |
# 97
# | Epoch: 98 | Train Loss: 0.691 | Train Acc: 76.37% | Val. Loss: 0.641 | Val. Acc: 78.28% |
# 98
# | Epoch: 99 | Train Loss: 0.686 | Train Acc: 76.45% | Val. Loss: 0.630 | Val. Acc: 78.22% |
# 99
# | Epoch: 100 | Train Loss: 0.690 | Train Acc: 76.43% | Val. Loss: 0.652 | Val. Acc: 77.69% |

# %%
#3. OUTPUT

model.load_state_dict(torch.load(MODEL_SAVE_PATH)) #Load best weights from file
test_loss, test_acc = common.evaluate(model, device, valid_iterator, criterion) #Test Loss is dependent on
print(f'| Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:05.2f}%')
# Out:
# | Test Loss: 0.634 | Test Acc: 78.62%
