# %%
# !pip3 install --user ipykernel
# !python3 -m ipykernel install --user --name=aue8930
# !jupyter kernelspec list
#!jupyter kernelspec uninstall aue8930
# !conda install --yes matplotlib
# Out:
# Requirement already satisfied: ipykernel in /home/csamak/.local/lib/python3.6/site-packages (5.5.6)
# Requirement already satisfied: jupyter-client in /home/csamak/.local/lib/python3.6/site-packages (from ipykernel) (7.1.2)
# Requirement already satisfied: ipython>=5.0.0 in /home/csamak/.local/lib/python3.6/site-packages (from ipykernel) (7.16.3)
# Requirement already satisfied: ipython-genutils in /home/csamak/.local/lib/python3.6/site-packages (from ipykernel) (0.2.0)
# Requirement already satisfied: tornado>=4.2 in /home/csamak/.local/lib/python3.6/site-packages (from ipykernel) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in /home/csamak/.local/lib/python3.6/site-packages (from ipykernel) (4.3.3)
# Requirement already satisfied: pexpect in /home/csamak/.local/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (4.8.0)
# Requirement already satisfied: backcall in /home/csamak/.local/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/csamak/.local/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (3.0.36)
# Requirement already satisfied: jedi<=0.17.2,>=0.10 in /home/csamak/.local/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (0.17.2)
# Requirement already satisfied: pygments in /home/csamak/.local/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (2.14.0)
# Requirement already satisfied: pickleshare in /home/csamak/.local/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/csamak/.conda/envs/aue8930/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (58.0.4)
# Requirement already satisfied: decorator in /home/csamak/.local/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (5.1.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/csamak/.local/lib/python3.6/site-packages (from jedi<=0.17.2,>=0.10->ipython>=5.0.0->ipykernel) (0.7.1)
# Requirement already satisfied: wcwidth in /home/csamak/.local/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel) (0.2.6)
# Requirement already satisfied: six in /home/csamak/.conda/envs/aue8930/lib/python3.6/site-packages (from traitlets>=4.1.0->ipykernel) (1.16.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/csamak/.local/lib/python3.6/site-packages (from jupyter-client->ipykernel) (4.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/csamak/.local/lib/python3.6/site-packages (from jupyter-client->ipykernel) (1.5.8)
# Requirement already satisfied: pyzmq>=13 in /home/csamak/.local/lib/python3.6/site-packages (from jupyter-client->ipykernel) (25.1.1)
# Requirement already satisfied: entrypoints in /home/csamak/.local/lib/python3.6/site-packages (from jupyter-client->ipykernel) (0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /home/csamak/.local/lib/python3.6/site-packages (from jupyter-client->ipykernel) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/csamak/.local/lib/python3.6/site-packages (from pexpect->ipython>=5.0.0->ipykernel) (0.7.0)
# Installed kernelspec aue8930 in /home/csamak/.local/share/jupyter/kernels/aue8930
# Available kernels:
#   aue8930    /home/csamak/.local/share/jupyter/kernels/aue8930
#   python3    /home/csamak/.local/share/jupyter/kernels/python3
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/csamak/.conda/envs/aue8930
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     expat-2.5.0                |       h6a678d5_0         172 KB
#     fontconfig-2.14.1          |       h52c9d5c_1         281 KB
#     gst-plugins-base-1.14.1    |       h6a678d5_1         2.2 MB
#     gstreamer-1.14.1           |       h5eee18b_1         1.7 MB
#     kiwisolver-1.3.1           |   py36h2531618_0          86 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxml2-2.9.14             |       h74e7548_0         718 KB
#     matplotlib-3.3.4           |   py36h06a4308_0          26 KB
#     matplotlib-base-3.3.4      |   py36h62a2d02_0         5.1 MB
#     pyqt-5.9.2                 |   py36h05f1152_2         4.5 MB
#     sip-4.19.8                 |   py36hf484d3e_0         274 KB
#     tornado-6.1                |   py36h27cfd23_0         581 KB
#     ------------------------------------------------------------
#                                            Total:        16.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   dbus               pkgs/main/linux-64::dbus-1.13.18-hb2f20db_0
#   expat              pkgs/main/linux-64::expat-2.5.0-h6a678d5_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h52c9d5c_1
#   glib               pkgs/main/linux-64::glib-2.69.1-h4ff587b_1
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.1-h6a678d5_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.1-h5eee18b_1
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.3.1-py36h2531618_0
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.14-h74e7548_0
#   matplotlib         pkgs/main/linux-64::matplotlib-3.3.4-py36h06a4308_0
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.3.4-py36h62a2d02_0
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pyparsing          pkgs/main/noarch::pyparsing-3.0.4-pyhd3eb1b0_0
#   pyqt               pkgs/main/linux-64::pyqt-5.9.2-py36h05f1152_2
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   qt                 pkgs/main/linux-64::qt-5.9.7-h5867ecd_1
#   sip                pkgs/main/linux-64::sip-4.19.8-py36hf484d3e_0
#   tornado            pkgs/main/linux-64::tornado-6.1-py36h27cfd23_0
#
#
#
# Downloading and Extracting Packages
# pyqt-5.9.2           | 4.5 MB    | ##################################### | 100%
# libxml2-2.9.14       | 718 KB    | ##################################### | 100%
# tornado-6.1          | 581 KB    | ##################################### | 100%
# matplotlib-3.3.4     | 26 KB     | ##################################### | 100%
# matplotlib-base-3.3. | 5.1 MB    | ##################################### | 100%
# fontconfig-2.14.1    | 281 KB    | ##################################### | 100%
# expat-2.5.0          | 172 KB    | ##################################### | 100%
# libxcb-1.15          | 505 KB    | ##################################### | 100%
# gst-plugins-base-1.1 | 2.2 MB    | ##################################### | 100%
# sip-4.19.8           | 274 KB    | ##################################### | 100%
# kiwisolver-1.3.1     | 86 KB     | ##################################### | 100%
# gstreamer-1.14.1     | 1.7 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import models
import os
import torch
from torch import optim, nn
from torchvision import transforms, datasets
import torchvision
import common
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#DIRECTORY SETTINGS
os.chdir("..")#Go up two directories
SAVE_DIR = 'models'
MODEL_SAVE_PATH = os.path.join(SAVE_DIR, 'two_gpu.pt')


#HYPERPARAMETERS
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

EPOCHS=100
BATCH_SIZE = 32
criterion = nn.CrossEntropyLoss()
ADAM_OPTIMISER=True
LEARNING_RATE=0.001

# %%
train_transforms = transforms.Compose([# Data Transforms
                           transforms.Resize(256),#Resize
                           transforms.RandomHorizontalFlip(30),#Flip
                           transforms.RandomRotation(10),#Roatate
                           transforms.RandomCrop(256),#Crop
                           transforms.ToTensor(),#Convert to Tensor
                           transforms.Normalize((0.49139968, 0.48215827, 0.44653124), (0.24703233, 0.24348505, 0.26158768))#Normalize
                       ])

test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.49139968, 0.48215827, 0.44653124), (0.24703233, 0.24348505, 0.26158768))
                       ])

# %%
train_data = torchvision.datasets.CIFAR10(root='data', train=True, download=True, transform=train_transforms)#Use CIFAR10 to train
train_data, valid_data = torch.utils.data.random_split(train_data, [int(len(train_data)*0.9), len(train_data) - int(len(train_data)*0.9)])
test_data = torchvision.datasets.CIFAR10(root='data', train=False, download=True, transform=test_transforms)


print(f'Number of training examples: {len(train_data)}')
print(f'Number of validation examples: {len(valid_data)}')
print(f'Number of testing examples: {len(test_data)}')


train_iterator = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=BATCH_SIZE)
valid_iterator = torch.utils.data.DataLoader(valid_data, batch_size=BATCH_SIZE)
test_iterator = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 45000
# Number of validation examples: 5000
# Number of testing examples: 10000

# %%
model = torchvision.models.resnet18(pretrained=True)#TorchVision

for param in model.parameters():
    param.requires_grad = False
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 10)
model = model.to(device)

model = nn.DataParallel(model)#Use data parallel architecture for using 2 GPU cores simultaneously

#Hyperparameters
if(ADAM_OPTIMISER):
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
else:
    optimizer = optim.SGD(model.classifier.parameters(), lr=0.001, momentum=0.5)

# %%
#Train
train_epoch_hist = []#List to store training epoch history
train_acc_hist = []#List to store training accuracy history

best_valid_loss = float('inf')
for epoch in range(EPOCHS):#Range of Epochs
    print(epoch)
    train_loss, train_acc = common.train(model, device, train_iterator, optimizer, criterion)#Train Loss Calculation
    valid_loss, valid_acc = common.evaluate(model, device, valid_iterator, criterion)#Validation Loss Calculation
    
    train_epoch_hist.append(epoch+1)#Append current epoch to history
    train_acc_hist.append(train_acc)#Append current accuracy to history   

    if valid_loss < best_valid_loss:#Validation Loss - Is current lower than the saved validation loss.
        best_valid_loss = valid_loss#Save the best loss (lowest)
        torch.save(model.state_dict(), MODEL_SAVE_PATH)#Save the model

    print(f'| Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:05.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:05.2f}% |')
# Out:
# 0
# | Epoch: 01 | Train Loss: 1.002 | Train Acc: 66.78% | Val. Loss: 0.764 | Val. Acc: 73.71% |
# 1
# | Epoch: 02 | Train Loss: 0.786 | Train Acc: 72.91% | Val. Loss: 0.784 | Val. Acc: 72.95% |
# 2
# | Epoch: 03 | Train Loss: 0.748 | Train Acc: 74.23% | Val. Loss: 0.674 | Val. Acc: 76.85% |
# 3
# | Epoch: 04 | Train Loss: 0.742 | Train Acc: 74.29% | Val. Loss: 0.698 | Val. Acc: 75.76% |
# 4
# | Epoch: 05 | Train Loss: 0.728 | Train Acc: 74.87% | Val. Loss: 0.701 | Val. Acc: 75.26% |
# 5
# | Epoch: 06 | Train Loss: 0.723 | Train Acc: 75.00% | Val. Loss: 0.671 | Val. Acc: 77.13% |
# 6
# | Epoch: 07 | Train Loss: 0.713 | Train Acc: 75.33% | Val. Loss: 0.687 | Val. Acc: 75.92% |
# 7
# | Epoch: 08 | Train Loss: 0.712 | Train Acc: 75.24% | Val. Loss: 0.663 | Val. Acc: 76.97% |
# 8
# | Epoch: 09 | Train Loss: 0.709 | Train Acc: 75.67% | Val. Loss: 0.656 | Val. Acc: 77.25% |
# 9
# | Epoch: 10 | Train Loss: 0.710 | Train Acc: 75.42% | Val. Loss: 0.655 | Val. Acc: 77.73% |
# 10
# | Epoch: 11 | Train Loss: 0.708 | Train Acc: 75.34% | Val. Loss: 0.666 | Val. Acc: 77.11% |
# 11
# | Epoch: 12 | Train Loss: 0.710 | Train Acc: 75.41% | Val. Loss: 0.656 | Val. Acc: 77.63% |
# 12
# | Epoch: 13 | Train Loss: 0.700 | Train Acc: 75.79% | Val. Loss: 0.664 | Val. Acc: 77.25% |
# 13
# | Epoch: 14 | Train Loss: 0.702 | Train Acc: 75.84% | Val. Loss: 0.651 | Val. Acc: 77.07% |
# 14
# | Epoch: 15 | Train Loss: 0.700 | Train Acc: 76.02% | Val. Loss: 0.652 | Val. Acc: 77.63% |
# 15
# | Epoch: 16 | Train Loss: 0.693 | Train Acc: 76.01% | Val. Loss: 0.657 | Val. Acc: 77.29% |
# 16
# | Epoch: 17 | Train Loss: 0.698 | Train Acc: 76.01% | Val. Loss: 0.644 | Val. Acc: 77.95% |
# 17
# | Epoch: 18 | Train Loss: 0.696 | Train Acc: 75.91% | Val. Loss: 0.672 | Val. Acc: 76.87% |
# 18
# | Epoch: 19 | Train Loss: 0.693 | Train Acc: 75.96% | Val. Loss: 0.701 | Val. Acc: 75.78% |
# 19
# | Epoch: 20 | Train Loss: 0.695 | Train Acc: 75.95% | Val. Loss: 0.639 | Val. Acc: 77.45% |
# 20
# | Epoch: 21 | Train Loss: 0.694 | Train Acc: 76.12% | Val. Loss: 0.645 | Val. Acc: 77.63% |
# 21
# | Epoch: 22 | Train Loss: 0.698 | Train Acc: 76.00% | Val. Loss: 0.649 | Val. Acc: 77.33% |
# 22
# | Epoch: 23 | Train Loss: 0.694 | Train Acc: 75.94% | Val. Loss: 0.668 | Val. Acc: 76.95% |
# 23
# | Epoch: 24 | Train Loss: 0.694 | Train Acc: 76.09% | Val. Loss: 0.626 | Val. Acc: 78.14% |
# 24
# | Epoch: 25 | Train Loss: 0.697 | Train Acc: 75.92% | Val. Loss: 0.691 | Val. Acc: 75.86% |
# 25
# | Epoch: 26 | Train Loss: 0.697 | Train Acc: 75.72% | Val. Loss: 0.637 | Val. Acc: 77.87% |
# 26
# | Epoch: 27 | Train Loss: 0.692 | Train Acc: 75.99% | Val. Loss: 0.647 | Val. Acc: 77.37% |
# 27
# | Epoch: 28 | Train Loss: 0.692 | Train Acc: 76.20% | Val. Loss: 0.640 | Val. Acc: 78.01% |
# 28
# | Epoch: 29 | Train Loss: 0.690 | Train Acc: 76.18% | Val. Loss: 0.668 | Val. Acc: 76.55% |
# 29
# | Epoch: 30 | Train Loss: 0.692 | Train Acc: 76.23% | Val. Loss: 0.674 | Val. Acc: 75.88% |
# 30
# | Epoch: 31 | Train Loss: 0.693 | Train Acc: 75.82% | Val. Loss: 0.667 | Val. Acc: 76.59% |
# 31
# | Epoch: 32 | Train Loss: 0.690 | Train Acc: 76.12% | Val. Loss: 0.659 | Val. Acc: 77.81% |
# 32
# | Epoch: 33 | Train Loss: 0.689 | Train Acc: 76.12% | Val. Loss: 0.642 | Val. Acc: 77.93% |
# 33
# | Epoch: 34 | Train Loss: 0.690 | Train Acc: 76.25% | Val. Loss: 0.677 | Val. Acc: 76.71% |
# 34
# | Epoch: 35 | Train Loss: 0.685 | Train Acc: 76.18% | Val. Loss: 0.650 | Val. Acc: 77.59% |
# 35
# | Epoch: 36 | Train Loss: 0.689 | Train Acc: 76.20% | Val. Loss: 0.646 | Val. Acc: 77.59% |
# 36
# | Epoch: 37 | Train Loss: 0.689 | Train Acc: 76.23% | Val. Loss: 0.659 | Val. Acc: 76.91% |
# 37
# | Epoch: 38 | Train Loss: 0.682 | Train Acc: 76.51% | Val. Loss: 0.652 | Val. Acc: 77.85% |
# 38
# | Epoch: 39 | Train Loss: 0.690 | Train Acc: 76.40% | Val. Loss: 0.647 | Val. Acc: 77.97% |
# 39
# | Epoch: 40 | Train Loss: 0.687 | Train Acc: 76.49% | Val. Loss: 0.667 | Val. Acc: 77.17% |
# 40
# | Epoch: 41 | Train Loss: 0.694 | Train Acc: 76.03% | Val. Loss: 0.643 | Val. Acc: 77.17% |
# 41
# | Epoch: 42 | Train Loss: 0.688 | Train Acc: 76.15% | Val. Loss: 0.656 | Val. Acc: 77.17% |
# 42
# | Epoch: 43 | Train Loss: 0.688 | Train Acc: 76.42% | Val. Loss: 0.660 | Val. Acc: 77.41% |
# 43
# | Epoch: 44 | Train Loss: 0.692 | Train Acc: 76.37% | Val. Loss: 0.637 | Val. Acc: 78.30% |
# 44
# | Epoch: 45 | Train Loss: 0.682 | Train Acc: 76.17% | Val. Loss: 0.669 | Val. Acc: 76.83% |
# 45
# | Epoch: 46 | Train Loss: 0.694 | Train Acc: 76.15% | Val. Loss: 0.638 | Val. Acc: 78.11% |
# 46
# | Epoch: 47 | Train Loss: 0.688 | Train Acc: 76.18% | Val. Loss: 0.645 | Val. Acc: 77.61% |
# 47
# | Epoch: 48 | Train Loss: 0.689 | Train Acc: 76.27% | Val. Loss: 0.622 | Val. Acc: 78.36% |
# 48
# | Epoch: 49 | Train Loss: 0.692 | Train Acc: 76.10% | Val. Loss: 0.626 | Val. Acc: 78.36% |
# 49
# | Epoch: 50 | Train Loss: 0.686 | Train Acc: 76.28% | Val. Loss: 0.664 | Val. Acc: 77.51% |
# 50
# | Epoch: 51 | Train Loss: 0.691 | Train Acc: 76.05% | Val. Loss: 0.647 | Val. Acc: 77.59% |
# 51
# | Epoch: 52 | Train Loss: 0.690 | Train Acc: 75.99% | Val. Loss: 0.654 | Val. Acc: 77.29% |
# 52
# | Epoch: 53 | Train Loss: 0.685 | Train Acc: 76.34% | Val. Loss: 0.651 | Val. Acc: 77.89% |
# 53
# | Epoch: 54 | Train Loss: 0.696 | Train Acc: 75.99% | Val. Loss: 0.646 | Val. Acc: 77.31% |
# 54
# | Epoch: 55 | Train Loss: 0.685 | Train Acc: 76.45% | Val. Loss: 0.663 | Val. Acc: 77.19% |
# 55
# | Epoch: 56 | Train Loss: 0.692 | Train Acc: 75.95% | Val. Loss: 0.673 | Val. Acc: 76.55% |
# 56
# | Epoch: 57 | Train Loss: 0.691 | Train Acc: 76.16% | Val. Loss: 0.638 | Val. Acc: 77.09% |
# 57
# | Epoch: 58 | Train Loss: 0.689 | Train Acc: 76.08% | Val. Loss: 0.652 | Val. Acc: 77.69% |
# 58
# | Epoch: 59 | Train Loss: 0.685 | Train Acc: 76.32% | Val. Loss: 0.658 | Val. Acc: 77.19% |
# 59
# | Epoch: 60 | Train Loss: 0.689 | Train Acc: 76.15% | Val. Loss: 0.653 | Val. Acc: 78.01% |
# 60
# | Epoch: 61 | Train Loss: 0.689 | Train Acc: 76.14% | Val. Loss: 0.675 | Val. Acc: 76.99% |
# 61
# | Epoch: 62 | Train Loss: 0.687 | Train Acc: 76.34% | Val. Loss: 0.616 | Val. Acc: 78.26% |
# 62
# | Epoch: 63 | Train Loss: 0.679 | Train Acc: 76.41% | Val. Loss: 0.672 | Val. Acc: 76.63% |
# 63
# | Epoch: 64 | Train Loss: 0.687 | Train Acc: 76.24% | Val. Loss: 0.637 | Val. Acc: 78.12% |
# 64
# | Epoch: 65 | Train Loss: 0.690 | Train Acc: 76.14% | Val. Loss: 0.650 | Val. Acc: 77.55% |
# 65
# | Epoch: 66 | Train Loss: 0.690 | Train Acc: 76.43% | Val. Loss: 0.656 | Val. Acc: 77.33% |
# 66
# | Epoch: 67 | Train Loss: 0.685 | Train Acc: 76.24% | Val. Loss: 0.652 | Val. Acc: 77.51% |
# 67
# | Epoch: 68 | Train Loss: 0.693 | Train Acc: 76.09% | Val. Loss: 0.634 | Val. Acc: 78.40% |
# 68
# | Epoch: 69 | Train Loss: 0.691 | Train Acc: 76.26% | Val. Loss: 0.658 | Val. Acc: 76.83% |
# 69
# | Epoch: 70 | Train Loss: 0.688 | Train Acc: 76.29% | Val. Loss: 0.654 | Val. Acc: 77.73% |
# 70
# | Epoch: 71 | Train Loss: 0.687 | Train Acc: 76.10% | Val. Loss: 0.635 | Val. Acc: 77.91% |
# 71
# | Epoch: 72 | Train Loss: 0.694 | Train Acc: 75.92% | Val. Loss: 0.628 | Val. Acc: 77.75% |
# 72
# | Epoch: 73 | Train Loss: 0.687 | Train Acc: 76.26% | Val. Loss: 0.645 | Val. Acc: 77.55% |
# 73
# | Epoch: 74 | Train Loss: 0.687 | Train Acc: 76.34% | Val. Loss: 0.642 | Val. Acc: 77.87% |
# 74
# | Epoch: 75 | Train Loss: 0.690 | Train Acc: 76.07% | Val. Loss: 0.649 | Val. Acc: 77.33% |
# 75
# | Epoch: 76 | Train Loss: 0.692 | Train Acc: 76.20% | Val. Loss: 0.628 | Val. Acc: 78.07% |
# 76
# | Epoch: 77 | Train Loss: 0.690 | Train Acc: 76.25% | Val. Loss: 0.629 | Val. Acc: 78.03% |
# 77
# | Epoch: 78 | Train Loss: 0.684 | Train Acc: 76.31% | Val. Loss: 0.659 | Val. Acc: 76.91% |
# 78
# | Epoch: 79 | Train Loss: 0.692 | Train Acc: 76.34% | Val. Loss: 0.643 | Val. Acc: 77.77% |
# 79
# | Epoch: 80 | Train Loss: 0.687 | Train Acc: 76.49% | Val. Loss: 0.643 | Val. Acc: 77.47% |
# 80
# | Epoch: 81 | Train Loss: 0.697 | Train Acc: 75.96% | Val. Loss: 0.657 | Val. Acc: 77.13% |
# 81
# | Epoch: 82 | Train Loss: 0.693 | Train Acc: 76.11% | Val. Loss: 0.636 | Val. Acc: 77.77% |
# 82
# | Epoch: 83 | Train Loss: 0.688 | Train Acc: 76.09% | Val. Loss: 0.635 | Val. Acc: 77.99% |
# 83
# | Epoch: 84 | Train Loss: 0.694 | Train Acc: 76.30% | Val. Loss: 0.678 | Val. Acc: 76.87% |
# 84
# | Epoch: 85 | Train Loss: 0.694 | Train Acc: 76.06% | Val. Loss: 0.635 | Val. Acc: 78.48% |
# 85
# | Epoch: 86 | Train Loss: 0.692 | Train Acc: 76.10% | Val. Loss: 0.628 | Val. Acc: 78.03% |
# 86
# | Epoch: 87 | Train Loss: 0.681 | Train Acc: 76.42% | Val. Loss: 0.666 | Val. Acc: 77.03% |
# 87
# | Epoch: 88 | Train Loss: 0.687 | Train Acc: 76.35% | Val. Loss: 0.641 | Val. Acc: 78.05% |
# 88
# | Epoch: 89 | Train Loss: 0.689 | Train Acc: 76.16% | Val. Loss: 0.663 | Val. Acc: 77.29% |
# 89
# | Epoch: 90 | Train Loss: 0.682 | Train Acc: 76.60% | Val. Loss: 0.654 | Val. Acc: 77.11% |
# 90
# | Epoch: 91 | Train Loss: 0.694 | Train Acc: 75.96% | Val. Loss: 0.655 | Val. Acc: 77.55% |
# 91
# | Epoch: 92 | Train Loss: 0.690 | Train Acc: 76.09% | Val. Loss: 0.655 | Val. Acc: 77.53% |
# 92
# | Epoch: 93 | Train Loss: 0.691 | Train Acc: 76.25% | Val. Loss: 0.644 | Val. Acc: 77.75% |
# 93
# | Epoch: 94 | Train Loss: 0.686 | Train Acc: 76.38% | Val. Loss: 0.626 | Val. Acc: 78.56% |
# 94
# | Epoch: 95 | Train Loss: 0.690 | Train Acc: 76.17% | Val. Loss: 0.666 | Val. Acc: 76.71% |
# 95
# | Epoch: 96 | Train Loss: 0.690 | Train Acc: 76.53% | Val. Loss: 0.634 | Val. Acc: 77.79% |
# 96
# | Epoch: 97 | Train Loss: 0.682 | Train Acc: 76.67% | Val. Loss: 0.654 | Val. Acc: 77.47% |
# 97
# | Epoch: 98 | Train Loss: 0.690 | Train Acc: 76.14% | Val. Loss: 0.632 | Val. Acc: 77.87% |
# 98
# | Epoch: 99 | Train Loss: 0.690 | Train Acc: 76.02% | Val. Loss: 0.640 | Val. Acc: 77.53% |
# 99
# | Epoch: 100 | Train Loss: 0.683 | Train Acc: 76.51% | Val. Loss: 0.679 | Val. Acc: 77.03% |

# %%
plt.figure(figsize=(12, 8))#Set figure size
plt.plot(train_epoch_hist, train_acc_hist)#Plot training accuracy against epochs
plt.title("Training Analysis")#Add title
plt.ylabel('train_acc')#Y-axis label
plt.xlabel('epoch')#X-axis label
plt.show()#Show plot

# %%
#3. OUTPUT

model.load_state_dict(torch.load(MODEL_SAVE_PATH)) #Load best weights from file
test_loss, test_acc = common.evaluate(model, device, valid_iterator, criterion) #Test Loss is dependent on
print(f'| Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:05.2f}%')
# Out:
# | Test Loss: 0.628 | Test Acc: 78.09%

# %%
#Perform a model inference for a certain image

import numpy as np

num_images = 5#Number of test images to use

transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])#Define transform
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)#Test dataset
testloader = torch.utils.data.DataLoader(testset, batch_size=num_images, shuffle=False, num_workers=2)#Test data loader
classes = ('Plane', 'Car', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck')

#Get model predictions on random testing images
dataiter = iter(testloader)
images, labels = next(dataiter)
outputs = model(images.to(device))
_, predicted = torch.max(outputs, 1)

def imshow(img):
    img = img / 2 + 0.5#Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

imshow(torchvision.utils.make_grid(images))#Show images
print('Ground Truth Labels : ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(num_images)))#Print ground truth labels
print('Model Predictions   : ', ' '.join(f'{classes[predicted[j]]:5s}' for j in range(num_images)))#Print model predictions
# Out:
# Files already downloaded and verified
# Ground Truth Labels :  Cat   Ship  Ship  Plane Frog
# Model Predictions   :  Cat   Bird  Ship  Ship  Frog
